# %% [markdown]
# Assignment 7: Data Analytics - III

# %%
import nltk
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: click in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nltk) (8.3.0)
# Requirement already satisfied: joblib in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nltk) (2025.9.18)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nltk) (4.67.1)
# Downloading nltk-3.9.4-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 799.8 kB/s  0:00:02773.8 kB/s eta 0:00:01
# Installing collected packages: nltk
# Successfully installed nltk-3.9.4
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /Users/raj/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /Users/raj/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /Users/raj/nltk_data...
# True

# %%
text = "Data Science is an amazing field. It includes Machine Learning, AI, and NLP."

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /Users/raj/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %% [markdown]
# Tokenization

# %%
tokens = word_tokenize(text)
print("Tokens:", tokens)
# Out:
# Tokens: ['Data', 'Science', 'is', 'an', 'amazing', 'field', '.', 'It', 'includes', 'Machine', 'Learning', ',', 'AI', ',', 'and', 'NLP', '.']

# %% [markdown]
# Stopword Removal

# %%
stop_words = set(stopwords.words('english'))
filtered = [word for word in tokens if word.lower() not in stop_words]
print("After Stopword Removal:", filtered)
# Out:
# After Stopword Removal: ['Data', 'Science', 'amazing', 'field', '.', 'includes', 'Machine', 'Learning', ',', 'AI', ',', 'NLP', '.']

# %% [markdown]
# Stemming

# %%
stemmer = PorterStemmer()
stemmed = [stemmer.stem(word) for word in filtered]
print("Stemmed Words:", stemmed)
# Out:
# Stemmed Words: ['data', 'scienc', 'amaz', 'field', '.', 'includ', 'machin', 'learn', ',', 'ai', ',', 'nlp', '.']

# %% [markdown]
# Lemmatization

# %%
lemmatizer = WordNetLemmatizer()
lemmatized = [lemmatizer.lemmatize(word) for word in filtered]
print("Lemmatized Words:", lemmatized)
# Out:
# Lemmatized Words: ['Data', 'Science', 'amazing', 'field', '.', 'includes', 'Machine', 'Learning', ',', 'AI', ',', 'NLP', '.']

# %% [markdown]
# TF-IDF VECTORIZATION

# %%
documents = [
    "I love machine learning",
    "Machine learning is fun",
    "Data science is amazing"
]

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(documents)

# %%
print("Feature Names:", vectorizer.get_feature_names_out())
print("TF-IDF Matrix:\n", X.toarray())
# Out:
# Feature Names: ['amazing' 'data' 'fun' 'is' 'learning' 'love' 'machine' 'science']
# TF-IDF Matrix:
#  [[0.         0.         0.         0.         0.51785612 0.68091856
#   0.51785612 0.        ]
#  [0.         0.         0.60465213 0.45985353 0.45985353 0.
#   0.45985353 0.        ]
#  [0.52863461 0.52863461 0.         0.40204024 0.         0.
#   0.         0.52863461]]
